# %%
# Accessing datas using Pandas
# look the previous file to learn the basic stuffs, "ultimate_pandas.ipynb"

# %%
import pandas as pd

# %%
coffee_data = pd.read_csv('DataSource/coffee.csv')

# %%
coffee_data
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# accessing values
coffee_data.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
# accessing value 
coffee_data['Day']
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee_data
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# sort values based on "Units Sold" column in descending order
coffee_data.sort_values("Units Sold", ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 9      Friday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
# sort values based on "Units Sold" column in ascending order
coffee_data.sort_values("Units Sold", ascending=True)
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 13     Sunday       Latte          35
# 11   Saturday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
# sort values based on "Units Sold" and "Coffee Type" column in ascending order
coffee_data.sort_values(["Units Sold","Coffee Type"], ascending=True)
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
# sort values based on "Units Sold" and "Day" column in ascending order
coffee_data.sort_values(["Units Sold","Day"], ascending=True)
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
# sort values based on "Units Sold" and "Day" column in ascending order
coffee_data.sort_values(["Day","Coffee Type"], ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 4   Wednesday    Espresso          35
# 3     Tuesday       Latte          20
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 6    Thursday    Espresso          40
# 13     Sunday       Latte          35
# 12     Sunday    Espresso          45
# 11   Saturday       Latte          35
# 10   Saturday    Espresso          45
# 1      Monday       Latte          15
# 0      Monday    Espresso          25
# 9      Friday       Latte          35
# 8      Friday    Espresso          45

# %%
# sort values based on "Units Sold" and "Day" column in ascending order
coffee_data.sort_values(["Units Sold","Coffee Type"], ascending=[0,1]) # here ascending order 0 for "Units Sold" and 1 for "Coffee Type"
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
# iteration (not recommanded)
for index, row in coffee_data.iterrows():
    print(index)
    print(row)
    print("\n\n")
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# ...

# %%
# iteration (not recommanded)
for index, row in coffee_data.items():
    print(index)
    print(row)
    print("\n\n")
# Out:
# Day
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object
#
#
#
# Coffee Type
# 0     Espresso
# 1        Latte
# 2     Espresso
# 3        Latte
# 4     Espresso
# 5        Latte
# 6     Espresso
# 7        Latte
# 8     Espresso
# 9        Latte
# 10    Espresso
# 11       Latte
# 12    Espresso
# 13       Latte
# Name: Coffee Type, dtype: object
#
#
#
# Units Sold
# 0     25
# 1     15
# 2     30
# 3     20
# 4     35
# 5     25
# 6     40
# 7     30
# 8     45
# 9     35
# 10    45
# 11    35
# 12    45
# 13    35
# Name: Units Sold, dtype: int64

# %%
coffee_data
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
noc_region = pd.read_csv('DataSource/noc_regions.csv')
noc_region
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
noc_region['region'].unique()
# Out:
# array(['Afghanistan', 'Curacao', 'Albania', 'Algeria', 'Andorra',
#        'Angola', 'Antigua', 'Australia', 'Argentina', 'Armenia', 'Aruba',
#        'American Samoa', 'Austria', 'Azerbaijan', 'Bahamas', 'Bangladesh',
#        'Barbados', 'Burundi', 'Belgium', 'Benin', 'Bermuda', 'Bhutan',
#        'Bosnia and Herzegovina', 'Belize', 'Belarus', 'Czech Republic',
#        'Boliva', 'Botswana', 'Brazil', 'Bahrain', 'Brunei', 'Bulgaria',
#        'Burkina Faso', 'Central African Republic', 'Cambodia', 'Canada',
#        'Cayman Islands', 'Republic of Congo', 'Chad', 'Chile', 'China',
#        'Ivory Coast', 'Cameroon', 'Democratic Republic of the Congo',
#        'Cook Islands', 'Colombia', 'Comoros', 'Cape Verde', 'Costa Rica',
#        'Croatia', 'Greece', 'Cuba', 'Cyprus', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'Eritrea',
#        'El Salvador', 'Spain', 'Estonia', 'Ethiopia', 'Russia', 'Fiji',
# ...

# %%
coffee_data
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# filter values based on values , not based on raws and columns indexes
coffee_data.loc[coffee_data['Day']=="Friday"]
# Out:
#       Day Coffee Type  Units Sold
# 8  Friday    Espresso          45
# 9  Friday       Latte          35

# %%
# filter values based on values , not based on raws and columns indexes
coffee_data['Day'] == "Friday"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# Name: Day, dtype: bool

# %%
# filter values based on values , not based on raws and columns indexes
coffee_data.loc[coffee_data['Day']=="Saturday"]
# Out:
#          Day Coffee Type  Units Sold
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35

# %%
# filter values based on values , not based on raws and columns indexes
coffee_data.loc[coffee_data['Units Sold'] < 20]
# Out:
#       Day Coffee Type  Units Sold
# 1  Monday       Latte          15

# %%
# filter using multiple conditions
# filter values based on values , not based on raws and columns indexes

coffee_data.loc[(coffee_data['Day'] =="Friday") & (coffee_data['Units Sold'] < 40)]
# Out:
#       Day Coffee Type  Units Sold
# 9  Friday       Latte          35

# %%
# filter values based on values , not based on raws and columns indexes
less_31_units = coffee_data.loc[coffee_data['Units Sold'] < 31]
less_31_units
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 5  Wednesday       Latte          25
# 7   Thursday       Latte          30

# %%
# Task: show me the number of units that sold bellow 31 units per day
less_31_units.sort_values('Units Sold', ascending=True).
# Out:
#          Day Coffee Type  Units Sold
# 1     Monday       Latte          15
# 3    Tuesday       Latte          20
# 0     Monday    Espresso          25
# 5  Wednesday       Latte          25
# 2    Tuesday    Espresso          30
# 7   Thursday       Latte          30

# %%
# filter values based on values and sort items, not based on raws and columns indexes
less_31_units = coffee_data.loc[coffee_data['Units Sold'] < 31].sort_values('Units Sold', ascending=True)
less_31_units
# Out:
#          Day Coffee Type  Units Sold
# 1     Monday       Latte          15
# 3    Tuesday       Latte          20
# 0     Monday    Espresso          25
# 5  Wednesday       Latte          25
# 2    Tuesday    Espresso          30
# 7   Thursday       Latte          30

# %%
# Task: show me only the data of latte coffee.
latte_data = coffee_data.loc[coffee_data['Coffee Type'] == "Latte"]
latte_data
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35

# %%
# Task: show me only the data of latte coffee having "coffee type" and "Units Sold" Columns
latte_data = coffee_data.loc[coffee_data['Coffee Type'] == "Latte", ["Coffee Type", "Units Sold"]]
latte_data
# Out:
#    Coffee Type  Units Sold
# 1        Latte          15
# 3        Latte          20
# 5        Latte          25
# 7        Latte          30
# 9        Latte          35
# 11       Latte          35
# 13       Latte          35

# %%
# Task: show me only the data of latte coffee having "Day" and "Units Sold" Columns
# another way
latte_data = coffee_data.loc[coffee_data['Coffee Type'] == "Latte"][["Day", "Coffee Type"]]
latte_data
# Out:
#           Day Coffee Type
# 1      Monday       Latte
# 3     Tuesday       Latte
# 5   Wednesday       Latte
# 7    Thursday       Latte
# 9      Friday       Latte
# 11   Saturday       Latte
# 13     Sunday       Latte

# %%
# Task: show me the data of Latte coffee which sold bellow 31 units 
latte_less_31
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35

# %%
noc_region
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
april_sales = pd.read_csv('DataSource/Sales_April_2019.csv')

# %%
april_sales
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
noc_region
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
# filter data using string and it's built in funtion ".isin()"


noc_region[noc_region['NOC'].isin(["USA","UK","GBR","AFG","IND","ALB"]) ]
# Out:
#      NOC       region notes
# 0    AFG  Afghanistan   NaN
# 2    ALB      Albania   NaN
# 74   GBR           UK   NaN
# 92   IND        India   NaN
# 216  USA          USA   NaN

# %%
# filter data using "query" 
noc_region.query('NOC =="USA"')
# Out:
#      NOC region notes
# 216  USA    USA   NaN

# %%
pokemon_Data = pd.read_csv('DataSource/pokemon_data.csv')
pokemon_Data
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# task: filter from ppokemon_Data of HP which are bellow 30
pokemon_Data.query('HP < 30 ')
# Out:
#        #       Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 55    50    Diglett    Ground    NaN  10      55       25       35       45
# 68    63       Abra   Psychic    NaN  25      20       15      105       55
# 88    81  Magnemite  Electric  Steel  25      35       70       95       55
# 139  129   Magikarp     Water    NaN  20      10       55       15       20
# 186  172      Pichu  Electric    NaN  20      40       15       35       35
# 230  213    Shuckle       Bug   Rock  20      10      230       10      230
# 303  280      Ralts   Psychic  Fairy  28      25       25       45       35
# 316  292   Shedinja       Bug  Ghost   1      90       45       30       30
# 381  349     Feebas     Water    NaN  20      15       20       10       55
# 388  355    Duskull     Ghost    NaN  20      40       90       30       90
# 487  439   Mime Jr.   Psychic  Fairy  20      25       45       70       90
#
#      Speed  Generation  Legendary
# ...

# %%
# task: filter from ppokemon_Data of HP and Attack which are bellow 30
pokemon_Data.query('HP < 30 & Attack < 30')
# Out:
#        #      Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 68    63      Abra  Psychic    NaN  25      20       15      105       55
# 139  129  Magikarp    Water    NaN  20      10       55       15       20
# 230  213   Shuckle      Bug   Rock  20      10      230       10      230
# 303  280     Ralts  Psychic  Fairy  28      25       25       45       35
# 381  349    Feebas    Water    NaN  20      15       20       10       55
# 487  439  Mime Jr.  Psychic  Fairy  20      25       45       70       90
#
#      Speed  Generation  Legendary
# 68      90           1      False
# 139     80           1      False
# 230      5           2      False
# 303     40           3      False
# 381     80           3      False
# 487     60           4      False

# %%
coffee_data
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35
