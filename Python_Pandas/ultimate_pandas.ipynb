# %%
# create dataframe
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3,4],["Arif","Rafin","Harun","Rock"],[2.5,5.5,6.7,32],[2.5,5,6,32]])
df
# Out:
#       0      1      2     3
# 0     1      2      3     4
# 1  Arif  Rafin  Harun  Rock
# 2   2.5    5.5    6.7    32
# 3   2.5      5      6    32

# %%
df.head()
# Out:
#       0      1      2     3
# 0     1      2      3     4
# 1  Arif  Rafin  Harun  Rock
# 2   2.5    5.5    6.7    32
# 3   2.5      5      6    32

# %%
df.tail()
# Out:
#       0      1      2     3
# 0     1      2      3     4
# 1  Arif  Rafin  Harun  Rock
# 2   2.5    5.5    6.7    32
# 3   2.5      5      6    32

# %%
df.tail(2)
# Out:
#      0    1    2   3
# 2  2.5  5.5  6.7  32
# 3  2.5    5    6  32

# %%
df.head(1)
# Out:
#    0  1  2  3
# 0  1  2  3  4

# %%
# modify columns name
df.columns=["A","B","C","D"]
df
# Out:
#       A      B      C     D
# 0     1      2      3     4
# 1  Arif  Rafin  Harun  Rock
# 2   2.5    5.5    6.7    32
# 3   2.5      5      6    32

# %%
# dataframe size 
df.size #output: 16, because there is total 16 elements in this dataframe.
# Out:
# 16

# %%
# let us know aboout how many raws and columns in this dataframe
df.shape   #(raw,column)
# Out:
# (4, 4)

# %%
# know information regarding the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      object
#  1   B       4 non-null      object
#  2   C       4 non-null      object
#  3   D       4 non-null      object
# dtypes: object(4)
# memory usage: 260.0+ bytes

# %%
# know some mathmathical information of the dataframe for each column 
df.describe()
# Out:
#           A  B  C   D
# count   4.0  4  4   4
# unique  3.0  4  4   3
# top     2.5  2  3  32
# freq    2.0  1  1   2

# %%
display(df)
# Out:
#       A      B      C     D
# 0     1      2      3     4
# 1  Arif  Rafin  Harun  Rock
# 2   2.5    5.5    6.7    32
# 3   2.5      5      6    32

# %%
# to see unique values in the dataframe
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6260\3754219962.py in ?()
#       1 # to see unique values in the dataframe
# ----> 2 df.unique()
#
# C:\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
# to see unique "Number" values in the dataframe
df.nunique()
# Out:
# A    3
# B    4
# C    4
# D    3
# dtype: int64

# %%
# to see values of a column in series data structure
df['A'] #series
# Out:
# 0       1
# 1    Arif
# 2     2.5
# 3     2.5
# Name: A, dtype: object

# %%
# to see values of a column in dataFrame data structure
df[['A']]   # dataframe
# Out:
#       A
# 0     1
# 1  Arif
# 2   2.5
# 3   2.5

# %%
# to see values of a column in dataFrame data structure
type(df[['A']])   # dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
# see the values of multiple column 
df[['A','B']]
# Out:
#       A      B
# 0     1      2
# 1  Arif  Rafin
# 2   2.5    5.5
# 3   2.5      5

# %%
# see the values of multiple column 
df[['A','D']]
# Out:
#       A     D
# 0     1     4
# 1  Arif  Rock
# 2   2.5    32
# 3   2.5    32

# %%
# see the values of multiple column from head
df[['A','D']].head(2)
# Out:
#       A     D
# 0     1     4
# 1  Arif  Rock

# %%
# see the values of multiple column from tail
df[['A','D']].tail(1)
# Out:
#      A   D
# 3  2.5  32

# %%
df
# Out:
#       A      B      C     D
# 0     1      2      3     4
# 1  Arif  Rafin  Harun  Rock
# 2   2.5    5.5    6.7    32
# 3   2.5      5      6    32

# %%
# find unique numbers in a specific column
df['A'].unique()
# Out:
# array([1, 'Arif', 2.5], dtype=object)

# %%
# find unique numbers in a specific column
df['D'].unique()
# Out:
# array([4, 'Rock', 32], dtype=object)

# %%
# find unique numbers in a specific column
df['C'].unique()
# Out:
# array([3, 'Harun', 6.7, 6], dtype=object)

# %%
# Read data from csv file
df_pokemon = pd.read_csv('DataSource/pokemon_data.csv')
df_pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  Poison  45      49       49       65       65     45           1      False
# 1      2                Ivysaur    Grass  Poison  60      62       63       80       80     60           1      False
# 2      3               Venusaur    Grass  Poison  80      82       83      100      100     80           1      False
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123      122      120     80           1      False
# 4      4             Charmander     Fire     NaN  39      52       43       60       50     65           1      False
# ..   ...                    ...      ...     ...  ..     ...      ...      ...      ...    ...         ...        ...
# 795  719                Diancie     Rock   Fairy  50     100      150      100      150     50           6       True
# ...

# %%
df_pokemon.size
# Out:
# 9600

# %%
df_pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65       65     45           1      False
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80       80     60           1      False
# 2  3                   Venusaur  Grass  Poison  80      82       83      100      100     80           1      False
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122      120     80           1      False
# 4  4                 Charmander   Fire     NaN  39      52       43       60       50     65           1      False
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80       65     80           1      False
# 6  6                  Charizard   Fire  Flying  78      84       78      109       85    100           1      False
# ...

# %%
df_pokemon.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795  719              Diancie     Rock  Fairy  50     100      150      100      150     50           6       True
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160      110    110           6       True
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150      130     70           6       True
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170      130     80           6       True
# 799  721            Volcanion     Fire  Water  80     110      120      130       90     70           6       True

# %%
sales_april = pd.read_csv('DataSource/Sales_April_2019.csv')
sales_april
# Out:
#       Order ID                     Product  ...      Order Date                        Purchase Address
# 0       176558        USB-C Charging Cable  ...  04/19/19 08:46            917 1st St, Dallas, TX 75001
# 1          NaN                         NaN  ...             NaN                                     NaN
# 2       176559  Bose SoundSport Headphones  ...  04/07/19 22:30       682 Chestnut St, Boston, MA 02215
# 3       176560                Google Phone  ...  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# 4       176560            Wired Headphones  ...  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# ...        ...                         ...  ...             ...                                     ...
# 18378   194090                Google Phone  ...  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001
# 18379   194091       AA Batteries (4-pack)  ...  04/15/19 16:02         311 Forest St, Austin, TX 73301
# ...

# %%
sales_april.size
# Out:
# 110298

# %%
sales_april.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18383 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18324 non-null  object
#  1   Product           18324 non-null  object
#  2   Quantity Ordered  18324 non-null  object
#  3   Price Each        18324 non-null  object
#  4   Order Date        18324 non-null  object
#  5   Purchase Address  18324 non-null  object
# dtypes: object(6)
# memory usage: 861.8+ KB

# %%
sales_april.describe()
# Out:
#         Order ID                   Product Quantity Ordered Price Each  Order Date  Purchase Address
# count      18324                     18324            18324      18324       18324             18324
# unique     17538                        20                8         19       13584             17120
# top     Order ID  Lightning Charging Cable                1      14.95  Order Date  Purchase Address
# freq          35                      2201            16558       2201          35                35

# %%
sales_april
# Out:
#       Order ID                   Product  ...      Order Date                        Purchase Address
# 0       176558  Lightning Charging Cable  ...  04/19/19 08:46            917 1st St, Dallas, TX 75001
# 1          NaN  Lightning Charging Cable  ...             NaN                                     NaN
# 2       176559  Lightning Charging Cable  ...  04/07/19 22:30       682 Chestnut St, Boston, MA 02215
# 3       176560  Lightning Charging Cable  ...  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# 4       176560  Lightning Charging Cable  ...  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# ...        ...                       ...  ...             ...                                     ...
# 18378   194090  Lightning Charging Cable  ...  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001
# 18379   194091  Lightning Charging Cable  ...  04/15/19 16:02         311 Forest St, Austin, TX 73301
# ...

# %%
orders_data = pd.read_excel('DataSource/Orders-With Nulls.xlsx')
orders_data
# Out:
#       Order ID Order Date  Order Quantity       Sales  ... Unit Price       Customer Name  Customer Segment Product Category
# 0            3 2010-10-13               6    261.5400  ...      38.94  Muhammed MacIntyre    Small Business  Office Supplies
# 1            6 2012-02-20               2      6.9300  ...       2.08         Ruben Dartt         Corporate  Office Supplies
# 2           32 2011-07-15              26   2808.0800  ...     107.53       Liz Pelletier         Corporate        Furniture
# 3           32 2011-07-15              24   1761.4000  ...      70.89       Liz Pelletier         Corporate        Furniture
# 4           32 2011-07-15              23    160.2335  ...       7.99       Liz Pelletier         Corporate       Technology
# ...        ...        ...             ...         ...  ...        ...                 ...               ...              ...
# ...

# %%
coffee_data = pd.read_csv('DataSource/coffee.csv')
coffee_data
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# to see any sample data from a dataframe randomly order
coffee_data.sample(10)
# Out:
#           Day Coffee Type  Units Sold
# 12     Sunday    Espresso          45
# 11   Saturday       Latte          35
# 3     Tuesday       Latte          20
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 0      Monday    Espresso          25
# 6    Thursday    Espresso          40
# 13     Sunday       Latte          35
# 5   Wednesday       Latte          25
# 1      Monday       Latte          15

# %%
# to see any sample data from a dataframe randomly order and not to change the format
coffee_data.sample(10, random_state=1)
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          20
# 7    Thursday       Latte          30
# 6    Thursday    Espresso          40
# 2     Tuesday    Espresso          30
# 10   Saturday    Espresso          45
# 4   Wednesday    Espresso          35
# 1      Monday       Latte          15
# 12     Sunday    Espresso          45
# 0      Monday    Espresso          25
# 13     Sunday       Latte          35

# %%
# *** To Access Specific values use "loc" and "iloc" *****

# loc use to filter raws and columns
# sample: coffee_data.loc[#Rows, #Columns]

# iloc

# %%
coffee_data
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee_data.loc[0]  # getting first raw values in series structure
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee_data.loc[[0]]   # getting first raw values in dataframe structure
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25

# %%
# get first 3 raws data in dataframe format 
coffee_data.loc[[0,1,2]]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
# get 3 raws data in dataframe format 
coffee_data.loc[[0,11,2]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 11  Saturday       Latte          35
# 2    Tuesday    Espresso          30

# %%
# get 6 raws data in dataframe format 
coffee_data.loc[[0,11,2,5,3]]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 11   Saturday       Latte          35
# 2     Tuesday    Espresso          30
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
